# %% [markdown]
# Hardware refers to the physical components of a computer that you can touch, such as a CPU or RAM. Software refers to programs and instructions that run on hardware, like operating systems or applications. For example, a CPU is hardware, while Windows OS is software.
